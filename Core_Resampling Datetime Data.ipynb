# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticks

import missingno as miss

import seaborn as sns
import numpy as np
# import statsmodels.tsa.api as tsa

pd.set_option('display.float_format',lambda x:f"{x:,.2f}")

# %%
sns.set_context('notebook',font_scale=0.9)
plt.style.use(['ggplot'])

# %%
# importing date and time library
# we will use datetime class as it is the most flexible
import datetime as dt

# %%
df = pd.read_csv("Data/london_weather_MODIFIED - london_weather_MODIFIED.csv")
df
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0      19790101         2.00      7.00             52.00      2.30      -4.10
# 1      19790102         6.00      1.70             27.00      1.60      -2.60
# 2      19790103         5.00      0.00             13.00      1.30      -2.80
# 3      19790104         8.00      0.00             13.00     -0.30      -2.60
# 4      19790105         6.00      2.00             29.00      5.60      -0.80
# ...         ...          ...       ...               ...       ...        ...
# 15336  20201227         1.00      0.90             32.00      7.50       7.50
# 15337  20201228         7.00      3.70             38.00      3.60       1.10
# 15338  20201229         7.00      0.00             21.00      4.10       2.60
# 15339  20201230         6.00      0.40             22.00      5.60       2.70
# 15340  20201231         7.00      1.30             34.00      1.50      -0.80
#
# ...

# %%
df.dtypes
# Out:
# date                  int64
# cloud_cover         float64
# sunshine            float64
# global_radiation    float64
# max_temp            float64
# mean_temp           float64
# min_temp            float64
# precipitation       float64
# pressure            float64
# snow_depth          float64
# dtype: object

# %%
df.shape
# Out:
# (15341, 10)

# %%
df.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101         2.00      7.00             52.00      2.30      -4.10
# 1  19790102         6.00      1.70             27.00      1.60      -2.60
# 2  19790103         5.00      0.00             13.00      1.30      -2.80
# 3  19790104         8.00      0.00             13.00     -0.30      -2.60
# 4  19790105         6.00      2.00             29.00      5.60      -0.80
#
#    min_temp  precipitation   pressure  snow_depth
# 0     -7.50           0.40 101,900.00        9.00
# 1     -7.50           0.00 102,530.00        8.00
# 2     -7.20           0.00 102,050.00        4.00
# 3     -6.50           0.00 100,840.00        2.00
# 4     -1.40           0.00 102,250.00        1.00

# %% [markdown]
# # (Part 1) #1- Convert the date column to datetime dtype

# %%
# INCORRECT - does not parse dates correctly
pd.to_datetime(df['date'])
# Out:
# 0       1970-01-01 00:00:00.019790101
# 1       1970-01-01 00:00:00.019790102
# 2       1970-01-01 00:00:00.019790103
# 3       1970-01-01 00:00:00.019790104
# 4       1970-01-01 00:00:00.019790105
#                      ...
# 15336   1970-01-01 00:00:00.020201227
# 15337   1970-01-01 00:00:00.020201228
# 15338   1970-01-01 00:00:00.020201229
# 15339   1970-01-01 00:00:00.020201230
# 15340   1970-01-01 00:00:00.020201231
# Name: date, Length: 15341, dtype: datetime64[ns]

# %%
# CORRECT - properly recognizes dates and does not interpret them as seconds
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')
df['date']
# Out:
# 0       1979-01-01
# 1       1979-01-02
# 2       1979-01-03
# 3       1979-01-04
# 4       1979-01-05
#            ...
# 15336   2020-12-27
# 15337   2020-12-28
# 15338   2020-12-29
# 15339   2020-12-30
# 15340   2020-12-31
# Name: date, Length: 15341, dtype: datetime64[ns]

# %%
#verified dat is now changed to datetime
df.dtypes
# Out:
# date                datetime64[ns]
# cloud_cover                float64
# sunshine                   float64
# global_radiation           float64
# max_temp                   float64
# mean_temp                  float64
# min_temp                   float64
# precipitation              float64
# pressure                   float64
# snow_depth                 float64
# dtype: object

# %% [markdown]
# # (Part 1) #2 -Set the date column as the index

# %%
#Inspect the new index of your dataframe.
df = df.set_index('date')
df
# Out:
#             cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# date
# 1979-01-01         2.00      7.00             52.00      2.30      -4.10
# 1979-01-02         6.00      1.70             27.00      1.60      -2.60
# 1979-01-03         5.00      0.00             13.00      1.30      -2.80
# 1979-01-04         8.00      0.00             13.00     -0.30      -2.60
# 1979-01-05         6.00      2.00             29.00      5.60      -0.80
# ...                 ...       ...               ...       ...        ...
# 2020-12-27         1.00      0.90             32.00      7.50       7.50
# 2020-12-28         7.00      3.70             38.00      3.60       1.10
# 2020-12-29         7.00      0.00             21.00      4.10       2.60
# 2020-12-30         6.00      0.40             22.00      5.60       2.70
# 2020-12-31         7.00      1.30             34.00      1.50      -0.80
#
#             min_temp  precipitation   pressure  snow_depth
# date
# ...

# %%
df.index
# Out:
# DatetimeIndex(['1979-01-01', '1979-01-02', '1979-01-03', '1979-01-04',
#                '1979-01-05', '1979-01-06', '1979-01-07', '1979-01-08',
#                '1979-01-09', '1979-01-10',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', name='date', length=15341, freq=None)

# %% [markdown]
# # (Part 1) #3- Filter out only the required data:

# %% [markdown]
# ![image.png](attachment:d7657ce1-e5a1-49fd-8c07-30cbe81db653.png)

# %%
df = df.loc['2000':, ['precipitation', 'mean_temp', 'min_temp', 
                      'max_temp', 'snow_depth']]

df
# Out:
#             precipitation  mean_temp  min_temp  max_temp  snow_depth
# date
# 2000-01-01           0.00       7.00      4.90     10.80        0.00
# 2000-01-02           0.20       7.90      5.00     11.50        0.00
# 2000-01-03           6.00       9.40      7.20      9.50        0.00
# 2000-01-04           0.20       7.00      4.40     11.00        0.00
# 2000-01-05           0.80       6.40      1.90     10.80        0.00
# ...                   ...        ...       ...       ...         ...
# 2020-12-27           2.00       7.50      7.60      7.50         NaN
# 2020-12-28           0.20       1.10     -1.30      3.60         NaN
# 2020-12-29           0.00       2.60      1.10      4.10         NaN
# 2020-12-30           0.00       2.70     -0.10      5.60         NaN
# 2020-12-31           0.00      -0.80     -3.10      1.50         NaN
#
# [7671 rows x 5 columns]

# %% [markdown]
# # (Part 1)#4- Impute any missing values

# %%
df.isna().sum()
# Out:
# precipitation     390
# mean_temp         419
# min_temp          386
# max_temp          390
# snow_depth       1752
# dtype: int64

# %%
## interpolating temperature measures
df['mean_temp'] = df['mean_temp'].interpolate()
df['max_temp'] = df['max_temp'].interpolate()
df['min_temp'] = df['min_temp'].interpolate()

# %%
df.isna().sum()
# Out:
# precipitation     390
# mean_temp           0
# min_temp            0
# max_temp            0
# snow_depth       1752
# dtype: int64

# %%
# filling preciptation/snow with 0
df['precipitation'] = df['precipitation'].fillna(0)
df['snow_depth'] = df['snow_depth'].fillna(0)

# %%
df.isna().sum()
# Out:
# precipitation    0
# mean_temp        0
# min_temp         0
# max_temp         0
# snow_depth       0
# dtype: int64

# %%
# Check the data type of the index
print(df.index.dtype)
# Out:
# datetime64[ns]

# %%
df
# Out:
#             precipitation  mean_temp  min_temp  max_temp  snow_depth
# date
# 2000-01-01           0.00       7.00      4.90     10.80        0.00
# 2000-01-02           0.20       7.90      5.00     11.50        0.00
# 2000-01-03           6.00       9.40      7.20      9.50        0.00
# 2000-01-04           0.20       7.00      4.40     11.00        0.00
# 2000-01-05           0.80       6.40      1.90     10.80        0.00
# ...                   ...        ...       ...       ...         ...
# 2020-12-27           2.00       7.50      7.60      7.50        0.00
# 2020-12-28           0.20       1.10     -1.30      3.60        0.00
# 2020-12-29           0.00       2.60      1.10      4.10        0.00
# 2020-12-30           0.00       2.70     -0.10      5.60        0.00
# 2020-12-31           0.00      -0.80     -3.10      1.50        0.00
#
# [7671 rows x 5 columns]

# %% [markdown]
# ___

# %% [markdown]
# # Part 2)
# - Answer the Questions with Visualizations (Using the Correct Frequency)

# %% [markdown]
# ![image.png](attachment:098ed000-8d80-4314-b74d-954dc6aa24e8.png)

# %% [markdown]
# ___

# %% [markdown]
# # (Part 2) #Q1: What month had the most precipitation between 2000 through 2010?

# %% [markdown]
# ![image.png](attachment:14bd2cdd-bdba-4029-9d5e-d697cdbe4cb3.png)

# %% [markdown]
# ![image.png](attachment:7e0fe197-c94a-44e2-93fd-c4e6f44de42a.png)

# %% [markdown]
# ![image.png](attachment:501e53a2-9c20-4d5d-abdd-3c1e45c85046.png)

# %%
# Create a copy of the DataFrame
df_copy = df.copy()

# %%
# Check the data type of the index
print(df_copy.index.dtype)
# Out:
# datetime64[ns]

# %%
# Filter the DataFrame copy to include only data between 2000 and 2010
df_copy = df_copy.loc['2000-01-01':'2010-12-31']

# Resample the precipitation column to a Monthly frequency using .sum() as the aggregation method
monthly_precipitation = df_copy['precipitation'].resample('M').sum()

# Find the date and corresponding value for the max precipitation
max_precipitation_date = monthly_precipitation.idxmax()
max_precipitation_value = monthly_precipitation.max()


# Create subplots
fig, ax = plt.subplots(figsize=(12, 3))


# Plot the monthly precipitation on the same axis
monthly_precipitation.plot(ax=ax, label='Monthly Precipitation', color='orange')

# Add a vertical line at the date with the max precipitation
ax.axvline(x=max_precipitation_date, color='red', linestyle='--', label='Max Precipitation Date')

# Add label for the vertical line
ax.text(max_precipitation_date, max_precipitation_value, f"{max_precipitation_date.strftime('%B %Y')}\nMax Precipitation: {max_precipitation_value} mm", color='red')

# Add legend
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## - Answer November 2009 had the max preciptiation between 2000 and 2010.

# %% [markdown]
# _________

# %% [markdown]
# # (Part 2) #Q2: Which year between 2000-2020 had the coolest average temperature?

# %% [markdown]
# ![image.png](attachment:88b76ba9-4846-4897-8296-320d4a74387f.png)

# %% [markdown]
# ![image.png](attachment:527b3dab-809f-4d03-a879-d851e9e1ef8a.png)

# %%
from matplotlib.patheffects import withStroke
# Specify the outline parameters
outline_effect = withStroke(linewidth=3, foreground='black')

# %%
# Resample the mean_temp column to a Yearly frequency using .mean() as the aggregation method
yearly_mean_temp = df['mean_temp'].resample('Y').mean()

# Find the year and corresponding value for the lowest mean temperature
min_mean_temp_year = yearly_mean_temp.idxmin().year
min_mean_temp_value = yearly_mean_temp.min()

# Create a wide figure
fig, ax = plt.subplots(figsize=(12, 3))

# Plot the mean temperature data
#df['mean_temp'].plot(ax=ax, label='Mean Temperature', color='blue')

# Plot the yearly mean temperature on the same axis
yearly_mean_temp.plot(ax=ax, label='Yearly Mean Temperature', color='yellow')

# Add a vertical line at the date with the lowest mean temperature
ax.axvline(x=f'{min_mean_temp_year}-01-01', color='red', linestyle='--', label='Min Mean Temp Year')

# Add label for the vertical line
ax.text(f'{min_mean_temp_year}-01-01', min_mean_temp_value, f"{min_mean_temp_year}\nMin Mean Temperature: {min_mean_temp_value}°C", color='red', fontsize=12, fontweight='bold', path_effects=[outline_effect])


# Set title and labels
plt.title('Average Temperature')
plt.ylabel('Degrees')

# Customize the major x-axis ticks
ax.xaxis.set_major_locator(mdates.YearLocator(base=5))  # Major ticks every 5 years
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Use 4-digit years
plt.xticks(rotation=90)  # Rotate the major ticks' labels 90 degrees

# Customize the minor x-axis ticks
ax.xaxis.set_minor_locator(mdates.YearLocator())  # Minor ticks every 1 year
plt.minorticks_off()  # Do not label the minor ticks

# Add legend
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## - Answer 2010 had the coolest average temperature
